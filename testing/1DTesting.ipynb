# %%
import os, sys
os.chdir(r"C:\Users\smithm\OneDrive\[Docs]\IBBR\Projects\NMRPipe\NMRPype")
sys.path.append(r"C:\Users\smithm\OneDrive\[Docs]\IBBR\Projects\NMRPipe\NMRPype\utils")

# %%
from utils.nmrData import *
import matplotlib.pyplot as plt

# %%
data = NMRData('hf/h.fid')
len(data.np_data)
# Out:
# 16384

# %%
plt.plot(data.np_data.real)

# %%
data.fnZeroFill()
plt.plot(data.np_data.real)

# %%
data.fnFourierTransform()
data.deleteImaginary()
plt.plot(data.np_data)

# %%
newData = NMRData('out/test2.fid')
plt.plot(newData.np_data.real)

# %%
print('data params:')
print('FDF2APOD', data.getParam('NDAPOD', 1))
print('FDSIZE', data.getParam('FDSIZE'))
print('\nnewdata params:')
print('FDF2APOD', newData.getParam('NDAPOD',1))
print('FDSIZE', newData.getParam('FDSIZE'))
print('FDF2ZF', newData.getParam('NDZF',1))
print('\nFDF2FTFLAG:')
print(newData.getParam('NDFTFLAG', 1))
# Out:
# data params:
# FDF2APOD 32768.0
# FDSIZE 32768.0
#
# newdata params:
# FDF2APOD 26384.0
# FDSIZE 26384.0
# FDF2ZF 0.0
#
# FDF2FTFLAG:
# 0.0

# %%
data.np_data.shape
# Out:
# (32768,)

# %%
newData.np_data.shape
# Out:
# (26384,)
